# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/Users/akhilmaddu/desktop/pistons/w5d1/common-W5D1/Wine_student.csv')

# %%
df.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# 5             False             False        False           False      False
# 6             False             False        False           False      False
# 7             False             False        False           False      False
# 8             False             False        False           False      False
# 9             False             False        False           False      False
# 10            False             False        False           False      False
# ...

# %%
df['fixed acidity'].empty
# Out:
# False

# %%
df['volatile acidity'].empty
# Out:
# False

# %%
column_names=df.columns.tolist()

# %%
column_names
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
for column in column_names:
    mean=np.mean(df[column])
    df[column].fillna(mean)
#    df[column].fillna(df.mean(column),axis=1)

# %%
df.head(55)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
df['chlorides'].fillna(np.mean(df['chlorides']))
# Out:
# 0       0.076
# 1       0.098
# 2       0.092
# 3       0.075
# 4       0.076
# 5       0.075
# 6       0.069
# 7       0.065
# 8       0.073
# 9       0.071
# 10      0.097
# 11      0.071
# 12      0.089
# 13      0.114
# 14      0.176
# 15      0.170
# 16      0.092
# 17      0.368
# 18      0.086
# 19      0.341
# 20      0.077
# 21      0.082
# 22      0.106
# 23      0.084
# 24      0.085
# 25      0.080
# 26      0.080
# 27      0.106
# 28      0.080
# 29      0.082
#         ...
# 1569    0.056
# 1570    0.230
# 1571    0.038
# 1572    0.069
# 1573    0.075
# 1574    0.074
# 1575    0.060
# 1576    0.081
# 1577    0.076
# 1578    0.118
# 1579    0.053
# 1580    0.068
# 1581    0.053
# 1582    0.053
# 1583    0.074
# 1584    0.061
# 1585    0.066
# 1586    0.065
# 1587    0.066
# 1588    0.068
# 1589    0.073
# 1590    0.077
# 1591    0.089
# 1592    0.076
# 1593    0.068
# 1594    0.090
# 1595    0.062
# 1596    0.076
# 1597    0.075
# 1598    0.067
# ...

# %%
df['density'].fillna(np.mean(df['density']))
# Out:
# 0       0.99780
# 1       0.99680
# 2       0.99700
# 3       0.99800
# 4       0.99780
# 5       0.99780
# 6       0.99640
# 7       0.99460
# 8       0.99680
# 9       0.99780
# 10      0.99590
# 11      0.99780
# 12      0.99430
# 13      0.99740
# 14      0.99860
# 15      0.99860
# 16      0.99690
# 17      0.99680
# 18      0.99740
# 19      0.99690
# 20      0.99680
# 21      0.99820
# 22      0.99660
# 23      0.99680
# 24      0.99680
# 25      0.99550
# 26      0.99620
# 27      0.99660
# 28      0.99720
# 29      0.99640
#          ...
# 1569    0.99396
# 1570    0.99340
# 1571    0.99514
# 1572    0.99632
# 1573    0.99467
# 1574    0.99677
# 1575    0.99474
# 1576    0.99588
# 1577    0.99622
# 1578    0.99540
# 1579    0.99402
# 1580    0.99470
# 1581    0.99402
# 1582    0.99362
# 1583    0.99578
# 1584    0.99484
# 1585    0.99494
# 1586    0.99492
# 1587    0.99483
# 1588    0.99414
# 1589    0.99770
# 1590    0.99314
# 1591    0.99402
# 1592    0.99574
# ...

# %%
df['sulphates'].fillna(np.mean(df['sulphates']))
# Out:
# 0       0.56
# 1       0.68
# 2       0.65
# 3       0.58
# 4       0.56
# 5       0.56
# 6       0.46
# 7       0.47
# 8       0.57
# 9       0.80
# 10      0.54
# 11      0.80
# 12      0.52
# 13      1.56
# 14      0.88
# 15      0.93
# 16      0.75
# 17      1.28
# 18      0.50
# 19      1.08
# 20      0.53
# 21      0.65
# 22      0.91
# 23      0.53
# 24      0.63
# 25      0.56
# 26      0.59
# 27      0.91
# 28      0.55
# 29      0.59
#         ...
# 1569    0.57
# 1570    0.93
# 1571    0.65
# 1572    0.51
# 1573    0.67
# 1574    0.48
# 1575    0.64
# 1576    0.78
# 1577    0.60
# 1578    0.67
# 1579    0.60
# 1580    0.60
# 1581    0.60
# 1582    0.50
# 1583    0.62
# 1584    0.80
# 1585    0.84
# 1586    0.85
# 1587    0.66
# 1588    0.78
# 1589    0.54
# 1590    0.82
# 1591    0.56
# 1592    0.75
# 1593    0.82
# 1594    0.58
# 1595    0.76
# 1596    0.75
# 1597    0.71
# 1598    0.66
# Name: sulphates, Length: 1599, dtype: float64

# %%
df.head(50)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
clean_df=df.dropna( how='any')

# %%
clean_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
import seaborn as sns
corr = clean_df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.show()

# %%
#dimensions
clean_df.shape
# Out:
# (1562, 12)

# %%
#summary
clean_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1562.000000       1562.000000  1562.000000     1562.000000
# mean        8.325736          0.526924     0.271876        2.542125
# std         1.751497          0.179313     0.194753        1.420271
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.100000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.300000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1562.000000          1562.000000           1562.000000  1562.000000
# mean      0.087282            15.884443             46.238156     0.996743
# std       0.046938            10.484145             32.684767     0.001898
# ...
